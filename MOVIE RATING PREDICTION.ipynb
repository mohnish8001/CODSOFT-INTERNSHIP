# %% [markdown]
# # Task
# To provide insights into the spread and skewness of the numerical features in your dataset, visualize the distributions of 'Year', 'Duration', and 'Votes' using histograms or distribution plots.

# %% [markdown]
# ## Analyze Numerical Feature Distributions
#
# ### Subtask:
# Visualize the distribution of numerical features such as 'Year', 'Duration', and 'Votes' using histograms or distribution plots.

# %% [markdown]
# **Reasoning**:
# I will create a single figure with three subplots to visualize the distribution of 'Year', 'Duration', and 'Votes' using `sns.histplot`, ensuring each plot has a clear title and axis labels for better readability.

# %%
plt.figure(figsize=(18, 5))

# Distribution of Year
plt.subplot(1, 3, 1)
sns.histplot(df['Year'], kde=True, bins=20)
plt.title('Distribution of Year')
plt.xlabel('Year')
plt.ylabel('Frequency')

# Distribution of Duration
plt.subplot(1, 3, 2)
sns.histplot(df['Duration'], kde=True, bins=20)
plt.title('Distribution of Duration')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')

# Distribution of Votes
plt.subplot(1, 3, 3)
sns.histplot(df['Votes'], kde=True, bins=20)
plt.title('Distribution of Votes')
plt.xlabel('Number of Votes')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Train a Random Forest Regressor Model
#
# ### Subtask:
# Implement and train a Random Forest Regressor model, a more robust ensemble learning technique, using the same preprocessed features and train-test split. This model is expected to capture more complex relationships in the data compared to Linear Regression.

# %% [markdown]
# **Reasoning**:
# I will import the `RandomForestRegressor` model, instantiate it, and then train it using the `X_train` and `y_train` datasets as instructed.

# %%
from sklearn.ensemble import RandomForestRegressor

# Instantiate and train a Random Forest Regressor model
rf_model = RandomForestRegressor(random_state=42) # Added random_state for reproducibility
rf_model.fit(X_train, y_train)

print("Random Forest Regressor model trained successfully.")
# Out:
# Random Forest Regressor model trained successfully.

# %% [markdown]
# ## Evaluate Random Forest Model Performance
#
# ### Subtask:
# Calculate and print the Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared (R²) for the Random Forest Regressor model's predictions on the test set. These metrics will quantify the model's accuracy.

# %% [markdown]
# **Reasoning**:
# I will calculate and print the evaluation metrics (MAE, MSE, RMSE, R) for the Random Forest Regressor model's predictions on the test set.

# %%
y_pred_rf = rf_model.predict(X_test)

mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("\nRandom Forest Model Performance:")
print(f"MAE : {mae_rf}")
print(f"MSE : {mse_rf}")
print(f"RMSE: {rmse_rf}")
print(f"R  : {r2_rf}")
# Out:
# Random Forest Model Performance:
# MAE : 0.8353049242424243
# MSE : 1.2183476470959596
# RMSE: 1.103787863267195
# R  : 0.3446731938987354

# %% [markdown]
# ## Compare Model Performance
#
# ### Subtask:
# Present a side-by-side comparison of the evaluation metrics (MAE, MSE, RMSE, R²) from both the Linear Regression model and the newly trained Random Forest Regressor to highlight which model performs better.

# %% [markdown]
# **Reasoning**:
# To compare the models, I will print the evaluation metrics for both the Linear Regression and Random Forest models side-by-side, along with a concluding remark on which model performed better for each metric.

# %%
print("\n--- Model Performance Comparison ---")

print("\nLinear Regression Model Performance:")
print(f"MAE : {mae}")
print(f"MSE : {mse}")
print(f"RMSE: {rmse}")
print(f"R²  : {r2}")

print("\nRandom Forest Regressor Model Performance:")
print(f"MAE : {mae_rf}")
print(f"MSE : {mse_rf}")
print(f"RMSE: {rmse_rf}")
print(f"R²  : {r2_rf}")

print("\n--- Conclusion ---")
if mae_rf < mae:
    print(f"Random Forest has a lower MAE ({mae_rf:.3f} vs {mae:.3f}), indicating better absolute accuracy.")
else:
    print(f"Linear Regression has a lower MAE ({mae:.3f} vs {mae_rf:.3f}), indicating better absolute accuracy.")

if mse_rf < mse:
    print(f"Random Forest has a lower MSE ({mse_rf:.3f} vs {mse:.3f}), indicating better error magnitude.")
else:
    print(f"Linear Regression has a lower MSE ({mse:.3f} vs {mse_rf:.3f}), indicating better error magnitude.")

if rmse_rf < rmse:
    print(f"Random Forest has a lower RMSE ({rmse_rf:.3f} vs {rmse:.3f}), indicating better error magnitude in the original units.")
else:
    print(f"Linear Regression has a lower RMSE ({rmse:.3f} vs {rmse_rf:.3f}), indicating better error magnitude in the original units.")

if r2_rf > r2:
    print(f"Random Forest has a higher R² ({r2_rf:.3f} vs {r2:.3f}), explaining more variance in the target variable.")
else:
    print(f"Linear Regression has a higher R² ({r2:.3f} vs {r2_rf:.3f}), explaining more variance in the target variable.")
# Out:
# --- Model Performance Comparison ---
#
# Linear Regression Model Performance:
# MAE : 1.031246622704767
# MSE : 1.6719944732712393
# RMSE: 1.293056252941549
# R²  : 0.10066490414331841
#
# Random Forest Regressor Model Performance:
# MAE : 0.8353049242424243
# MSE : 1.2183476470959596
# RMSE: 1.103787863267195
# R²  : 0.3446731938987354
#
# --- Conclusion ---
# Random Forest has a lower MAE (0.835 vs 1.031), indicating better absolute accuracy.
# Random Forest has a lower MSE (1.218 vs 1.672), indicating better error magnitude.
# Random Forest has a lower RMSE (1.104 vs 1.293), indicating better error magnitude in the original units.
# Random Forest has a higher R² (0.345 vs 0.101), explaining more variance in the target variable.

# %% [markdown]
# ## Visualize Random Forest Predictions
#
# ### Subtask:
# Create a scatter plot comparing the actual movie ratings (y_test) against the predicted ratings (y_pred_rf) from the Random Forest Regressor. Include appropriate labels and a title to visualize the model's predictive accuracy.

# %% [markdown]
# **Reasoning**:
# To visualize the Random Forest Regressor's predictive accuracy, I will create a scatter plot comparing actual ratings (`y_test`) against predicted ratings (`y_pred_rf`), adding clear labels and a title for better understanding.

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(x=y_test, y=y_pred_rf)
plt.xlabel("Actual Ratings")
plt.ylabel("Predicted Ratings (Random Forest)")
plt.title("Actual vs. Predicted Movie Ratings (Random Forest Regressor)")
plt.show()

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the findings from both models and recommend which model is more suitable for movie rating prediction based on the evaluation metrics.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Numerical Feature Distributions**:
#     *   **Year**: The distribution of movie release years was visualized, showing the frequency of movies across different years.
#     *   **Duration**: The distribution of movie durations was displayed, indicating the common lengths of films.
#     *   **Votes**: The distribution of votes was shown, generally skewed towards lower vote counts.
# *   **Model Performance Comparison**:
#     *   **Random Forest Regressor** demonstrated superior performance compared to the Linear Regression model across all evaluated metrics.
#     *   **Mean Absolute Error (MAE)**: Random Forest (0.835) was lower than Linear Regression (1.031), indicating better absolute accuracy.
#     *   **Mean Squared Error (MSE)**: Random Forest (1.218) was lower than Linear Regression (1.672), showing smaller error magnitudes.
#     *   **Root Mean Squared Error (RMSE)**: Random Forest (1.104) was lower than Linear Regression (1.293), suggesting better error magnitude in the original units.
#     *   **R-squared (R²)**: Random Forest (0.345) was significantly higher than Linear Regression (0.101), indicating it explains a much greater proportion of the variance in movie ratings.
#
# ### Insights or Next Steps
#
# *   The **Random Forest Regressor** is a more suitable model for movie rating prediction given its substantially better performance metrics (lower MAE, MSE, RMSE, and higher R²) compared to the Linear Regression model. This suggests that the relationship between features and movie ratings is non-linear and complex, which ensemble methods like Random Forest are better equipped to capture.
# *   To further improve the Random Forest model's performance, consider hyperparameter tuning (e.g., `n_estimators`, `max_depth`, `min_samples_split`) or exploring other advanced ensemble techniques like Gradient Boosting.
